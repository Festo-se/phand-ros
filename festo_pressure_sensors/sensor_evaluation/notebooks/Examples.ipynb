# %%
# Library imports
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Import of plotting functions
# Plotting functions are saved in a separate python file for notebook readibility

# %%
# Dirty way to import all functions in Jupyter
from sensor_evaluation.plot_functions import *
from sensor_evaluation.helpers import *

# %%
# Load data from .csv file
DATA_FOLDER = '../data/pts_2kg/'
DATA_SAMPLE = '2C_pts_2kg.csv'

df, sample_name = get_sample(DATA_SAMPLE, DATA_FOLDER)

# %%
# Example of time plot
time_plot(df, sample_name)

# %%
# Example of max plot
max_plot(df, sample_name)

# %%
# Example of box plot without outliers
box_plot(df, sample_name, None, 0, '')

# %%
# max map example
max_map(df, sample_name)

# %%
# avg map example
avg_map(df, sample_name)
